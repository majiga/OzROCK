# %% [markdown]
# # Similarity Measures
# ### Functions measuring similarity using graph edit distance.
# #### The graph edit distance is the number of edge/node changes needed to make two graphs isomorphic.

# %%
import os, glob
import time, datetime
import csv
import networkx as nx
import simplejson as json
from pathlib import Path

def save_graph(graph, fname):
    nodes = [{'id': n, 'group': graph.nodes[n]['group'], 'degree': str(graph.nodes[n]['degree'])} for n in graph.nodes()]
    links = [{'source': u, 'target': v, 'label': d['label']} for u, v, d in graph.edges(data=True)]
    with open(fname, 'w') as f:
        json.dump({'nodes': nodes, 'links': links}, f, indent=4,)
    #print('Graph file %s is created.', fname)

def load_graph(filename, name):
    d = json.load(open(filename))
    g = nx.DiGraph(name=name)
    for n in d['nodes']:
        if n['group'] != 'OTHER':
            g.add_node(n['id'], group = n['group'], degree = n['degree'])
    for n in d['links']:
        g.add_edge(n['source'], n['target'], label = n['label'])
    return g

start_all_time = time.time()
print('STARTED: ', datetime.datetime.now())
# Out:
# STARTED:  2020-06-30 13:04:15.679673

# %% [markdown]
# #### 1. Identifying new nodes, removed nodes, new links and removed links

# %%
def calculate_similarity(folder_name):
    files = glob.glob(os.path.join(folder_name, '*.json'))
    num_files = len(files)
    print(f"Total number of input files in '{folder_name}' folder is {num_files}.")
    similariy_scores = []

    for i in range(0, num_files-1):
        G1 = load_graph(files[i], 'G1')

        for j in range(i+1, num_files):
            try:
                #start_time = time.time()
                print(f'\n====================================\nFILE 1: {Path(files[i]).name} - Graph', nx.info(G1), '\n')

                G2 = load_graph(files[j], 'G2')
                print(f'FILE 2: {Path(files[j]).name} - Graph', nx.info(G2), '\n')

                # Total nodes in both graphs
                total_nodes = list(set(G1.nodes()).union(G2.nodes()))
                print('NODE INFORMATION:\nTotal nodes in both: ', len(total_nodes)) # , '\n', same_nodes)

                # The same nodes
                same_nodes = list(set(G1.nodes()).intersection(G2.nodes()))
                print('Same nodes in both: ', len(same_nodes)) # , '\n', same_nodes)

                # New nodes in G1
                node_difference1 = list(set(G1) - set(G2))
                print('Different nodes in G1: ', len(node_difference1)) # , '\n', difference1)

                # New nodes in G2
                node_difference2 = list(set(G2) - set(G1))
                print('Different nodes in G2: ', len(node_difference2)) # , '\n', difference2)

                if len(node_difference1) > len(node_difference2):
                    print(f'--- G1 has {len(node_difference1) - len(node_difference2)} more nodes than G2.')
                elif len(node_difference1) == 0 and len(node_difference2) == 0:
                    print(f'--- G1 = G2, has {len(node_difference1)} nodes.')
                else:
                    print(f'--- G2 has {len(node_difference2) - len(node_difference1)} more nodes than G1.')

                # Total links in both graphs
                total_links = list(set(G1.edges()).union(G2.edges()))
                print('\nLINK INFORMATION:\nTotal links in both: ', len(total_links)) # , '\n', same_nodes)

                # The same links
                same_links = list(set(G1.edges()).intersection(G2.edges()))
                print('Same links in both: ', len(same_links)) # , '\n', same_nodes)

                # New links in G1
                link_difference1 = list(set(G1.edges()) - set(G2.edges()))
                print('Different links in G1: ', len(link_difference1)) # , '\n') #, difference1)

                # New links in G2
                link_difference2 = list(set(G2.edges()) - set(G1.edges()))
                print('Different links in G2: ', len(link_difference2)) #, '\n') #, difference2)

                if len(link_difference1) > len(link_difference2):
                    print(f'--- G1 has {len(link_difference1) - len(link_difference2)} more links than G2.')
                elif len(link_difference1) == 0 and len(link_difference2) == 0:
                    print(f'--- G1 = G2, has {G1.nodes()} links.')
                else:
                    print(f'--- G2 has {len(link_difference2) - len(link_difference1)} more links than G1.')

                # Scoring
                sim_score = round(len(same_nodes + same_links)/len(total_nodes + total_links), 2)
                print(f"\n*** Similarity score = {sim_score:.2f}")
                similariy_scores.append([sim_score, Path(files[i]).name, Path(files[j]).name])

                #print("Duration = ", time.strftime("%H:%M:%S", time.gmtime(time.time() - start_time)), '\n')
                #break

            except Exception as ex:
                print("Error msg: " + str(ex))
                count_files_error += 1
                #break

    sorted_scores = sorted(similariy_scores, reverse = True)
    print('\nNum scores = ', len(similariy_scores)) #, len(sorted_scores))

    #print('\nSimilarity scores:', *sorted_scores, sep='\n')
    hours, rem = divmod(time.time() - start_all_time, 3600)
    minutes, seconds = divmod(rem, 60)
    print("Total processing time: {:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
    print('FINISHED: ', datetime.datetime.now())
    
    return sorted_scores

# %%
calculate_similarity(r"../wamex_data/wamex_graphs_fastest/gold/")
# Out:
# Total number of input files in '../wamex_data/wamex_graphs_fastest/gold/' folder is 4.
#
# ====================================
# FILE 1: gold_a084492_coolgardie_annual_report_2009_15818118.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 28
# Number of edges: 36
# Average in degree:   1.2857
# Average out degree:   1.2857
#
# FILE 2: gold_a074513_coolgardie_combined_annual_2006_final_13997651.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 178
# Number of edges: 678
# Average in degree:   3.8090
# Average out degree:   3.8090
#
# NODE INFORMATION:
# Total nodes in both:  185
# Same nodes in both:  21
# Different nodes in G1:  7
# Different nodes in G2:  157
# --- G2 has 150 more nodes than G1.
#
# LINK INFORMATION:
# Total links in both:  705
# Same links in both:  9
# Different links in G1:  27
# Different links in G2:  669
# --- G2 has 642 more links than G1.
#
# *** Similarity score = 0.03
#
# ====================================
# FILE 1: gold_a084492_coolgardie_annual_report_2009_15818118.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 28
# Number of edges: 36
# Average in degree:   1.2857
# Average out degree:   1.2857
#
# FILE 2: gold_a072821_coolgardie_combined_annual_2005_12942716.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 152
# Number of edges: 551
# Average in degree:   3.6250
# Average out degree:   3.6250
#
# NODE INFORMATION:
# Total nodes in both:  161
# Same nodes in both:  19
# Different nodes in G1:  9
# Different nodes in G2:  133
# --- G2 has 124 more nodes than G1.
#
# LINK INFORMATION:
# Total links in both:  577
# Same links in both:  10
# Different links in G1:  26
# Different links in G2:  541
# --- G2 has 515 more links than G1.
#
# *** Similarity score = 0.04
#
# ====================================
# FILE 1: gold_a084492_coolgardie_annual_report_2009_15818118.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 28
# Number of edges: 36
# Average in degree:   1.2857
# Average out degree:   1.2857
#
# FILE 2: gold_a076168_coolgardie annual report 2007_9968549.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 29
# Number of edges: 40
# Average in degree:   1.3793
# Average out degree:   1.3793
#
# NODE INFORMATION:
# Total nodes in both:  32
# Same nodes in both:  25
# Different nodes in G1:  3
# Different nodes in G2:  4
# --- G2 has 1 more nodes than G1.
#
# LINK INFORMATION:
# Total links in both:  48
# Same links in both:  28
# Different links in G1:  8
# Different links in G2:  12
# --- G2 has 4 more links than G1.
#
# *** Similarity score = 0.66
#
# ====================================
# FILE 1: gold_a074513_coolgardie_combined_annual_2006_final_13997651.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 178
# Number of edges: 678
# Average in degree:   3.8090
# Average out degree:   3.8090
#
# FILE 2: gold_a072821_coolgardie_combined_annual_2005_12942716.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 152
# Number of edges: 551
# Average in degree:   3.6250
# Average out degree:   3.6250
#
# NODE INFORMATION:
# Total nodes in both:  182
# Same nodes in both:  148
# Different nodes in G1:  30
# Different nodes in G2:  4
# --- G1 has 26 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  694
# Same links in both:  535
# Different links in G1:  143
# Different links in G2:  16
# --- G1 has 127 more links than G2.
#
# *** Similarity score = 0.78
#
# ====================================
# FILE 1: gold_a074513_coolgardie_combined_annual_2006_final_13997651.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 178
# Number of edges: 678
# Average in degree:   3.8090
# Average out degree:   3.8090
#
# FILE 2: gold_a076168_coolgardie annual report 2007_9968549.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 29
# Number of edges: 40
# Average in degree:   1.3793
# Average out degree:   1.3793
#
# NODE INFORMATION:
# Total nodes in both:  185
# Same nodes in both:  22
# Different nodes in G1:  156
# Different nodes in G2:  7
# --- G1 has 149 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  706
# Same links in both:  12
# Different links in G1:  666
# Different links in G2:  28
# --- G1 has 638 more links than G2.
#
# *** Similarity score = 0.04
#
# ====================================
# FILE 1: gold_a072821_coolgardie_combined_annual_2005_12942716.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 152
# Number of edges: 551
# Average in degree:   3.6250
# Average out degree:   3.6250
#
# FILE 2: gold_a076168_coolgardie annual report 2007_9968549.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 29
# Number of edges: 40
# Average in degree:   1.3793
# Average out degree:   1.3793
#
# NODE INFORMATION:
# Total nodes in both:  162
# Same nodes in both:  19
# Different nodes in G1:  133
# Different nodes in G2:  10
# --- G1 has 123 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  580
# Same links in both:  11
# Different links in G1:  540
# Different links in G2:  29
# --- G1 has 511 more links than G2.
#
# *** Similarity score = 0.04
#
# Num scores =  6
# Total processing time: 00:02:59.07
# FINISHED:  2020-06-30 13:07:14.748255
# [[0.78,
#   'gold_a074513_coolgardie_combined_annual_2006_final_13997651.json',
#   'gold_a072821_coolgardie_combined_annual_2005_12942716.json'],
#  [0.66,
#   'gold_a084492_coolgardie_annual_report_2009_15818118.json',
#   'gold_a076168_coolgardie annual report 2007_9968549.json'],
#  [0.04,
#   'gold_a084492_coolgardie_annual_report_2009_15818118.json',
#   'gold_a072821_coolgardie_combined_annual_2005_12942716.json'],
#  [0.04,
#   'gold_a074513_coolgardie_combined_annual_2006_final_13997651.json',
#   'gold_a076168_coolgardie annual report 2007_9968549.json'],
#  [0.04,
#   'gold_a072821_coolgardie_combined_annual_2005_12942716.json',
#   'gold_a076168_coolgardie annual report 2007_9968549.json'],
#  [0.03,
#   'gold_a084492_coolgardie_annual_report_2009_15818118.json',
#   'gold_a074513_coolgardie_combined_annual_2006_final_13997651.json']]

# %%
calculate_similarity(r"../wamex_data/wamex_graphs_fastest/iron_ore/")
# Out:
# Total number of input files in '../wamex_data/wamex_graphs_fastest/iron_ore/' folder is 7.
#
# ====================================
# G1: a078606_c125-1997-2008a_12703370.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 90
# Number of edges: 169
# Average in degree:   1.8778
# Average out degree:   1.8778
#
# G2: a072391_c125_2004_2006a_12728776.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 203
# Number of edges: 730
# Average in degree:   3.5961
# Average out degree:   3.5961
#
# NODE INFORMATION:
# Total nodes in both:  258
# Same nodes in both:  35
# Different nodes in G1:  55
# Different nodes in G2:  168
# --- G2 has 113 more nodes than G1.
#
# LINK INFORMATION:
# Total links in both:  889
# Same links in both:  10
# Different links in G1:  159
# Different links in G2:  720
# --- G2 has 561 more links than G1.
#
# *** Similarity score = 0.04
#
# ====================================
# G1: a078606_c125-1997-2008a_12703370.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 90
# Number of edges: 169
# Average in degree:   1.8778
# Average out degree:   1.8778
#
# G2: a086152_c125_1997_2010a_14952469.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 68
# Number of edges: 98
# Average in degree:   1.4412
# Average out degree:   1.4412
#
# NODE INFORMATION:
# Total nodes in both:  95
# Same nodes in both:  63
# Different nodes in G1:  27
# Different nodes in G2:  5
# --- G1 has 22 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  179
# Same links in both:  88
# Different links in G1:  81
# Different links in G2:  10
# --- G1 has 71 more links than G2.
#
# *** Similarity score = 0.55
#
# ====================================
# G1: a078606_c125-1997-2008a_12703370.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 90
# Number of edges: 169
# Average in degree:   1.8778
# Average out degree:   1.8778
#
# G2: a096981_c125_2010.2012a_15102718.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 74
# Number of edges: 111
# Average in degree:   1.5000
# Average out degree:   1.5000
#
# NODE INFORMATION:
# Total nodes in both:  145
# Same nodes in both:  19
# Different nodes in G1:  71
# Different nodes in G2:  55
# --- G1 has 16 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  278
# Same links in both:  2
# Different links in G1:  167
# Different links in G2:  109
# --- G1 has 58 more links than G2.
#
# *** Similarity score = 0.05
#
# ====================================
# G1: a078606_c125-1997-2008a_12703370.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 90
# Number of edges: 169
# Average in degree:   1.8778
# Average out degree:   1.8778
#
# G2: a086072_c125_2008_2009a_12463362.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 59
# Number of edges: 82
# Average in degree:   1.3898
# Average out degree:   1.3898
#
# NODE INFORMATION:
# Total nodes in both:  135
# Same nodes in both:  14
# Different nodes in G1:  76
# Different nodes in G2:  45
# --- G1 has 31 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  250
# Same links in both:  1
# Different links in G1:  168
# Different links in G2:  81
# --- G1 has 87 more links than G2.
#
# *** Similarity score = 0.04
#
# ====================================
# G1: a078606_c125-1997-2008a_12703370.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 90
# Number of edges: 169
# Average in degree:   1.8778
# Average out degree:   1.8778
#
# G2: a078348_c125_2004_2008a_15517251.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 45
# Number of edges: 74
# Average in degree:   1.6444
# Average out degree:   1.6444
#
# NODE INFORMATION:
# Total nodes in both:  125
# Same nodes in both:  10
# Different nodes in G1:  80
# Different nodes in G2:  35
# --- G1 has 45 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  241
# Same links in both:  2
# Different links in G1:  167
# Different links in G2:  72
# --- G1 has 95 more links than G2.
#
# *** Similarity score = 0.03
#
# ====================================
# G1: a078606_c125-1997-2008a_12703370.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 90
# Number of edges: 169
# Average in degree:   1.8778
# Average out degree:   1.8778
#
# G2: a075345_c125_2004_2007a_14419765.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 109
# Number of edges: 377
# Average in degree:   3.4587
# Average out degree:   3.4587
#
# NODE INFORMATION:
# Total nodes in both:  178
# Same nodes in both:  21
# Different nodes in G1:  69
# Different nodes in G2:  88
# --- G2 has 19 more nodes than G1.
#
# LINK INFORMATION:
# Total links in both:  543
# Same links in both:  3
# Different links in G1:  166
# Different links in G2:  374
# --- G2 has 208 more links than G1.
#
# *** Similarity score = 0.03
#
# ====================================
# G1: a072391_c125_2004_2006a_12728776.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 203
# Number of edges: 730
# Average in degree:   3.5961
# Average out degree:   3.5961
#
# G2: a086152_c125_1997_2010a_14952469.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 68
# Number of edges: 98
# Average in degree:   1.4412
# Average out degree:   1.4412
#
# NODE INFORMATION:
# Total nodes in both:  243
# Same nodes in both:  28
# Different nodes in G1:  175
# Different nodes in G2:  40
# --- G1 has 135 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  822
# Same links in both:  6
# Different links in G1:  724
# Different links in G2:  92
# --- G1 has 632 more links than G2.
#
# *** Similarity score = 0.03
#
# ====================================
# G1: a072391_c125_2004_2006a_12728776.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 203
# Number of edges: 730
# Average in degree:   3.5961
# Average out degree:   3.5961
#
# G2: a096981_c125_2010.2012a_15102718.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 74
# Number of edges: 111
# Average in degree:   1.5000
# Average out degree:   1.5000
#
# NODE INFORMATION:
# Total nodes in both:  253
# Same nodes in both:  24
# Different nodes in G1:  179
# Different nodes in G2:  50
# --- G1 has 129 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  839
# Same links in both:  2
# Different links in G1:  728
# Different links in G2:  109
# --- G1 has 619 more links than G2.
#
# *** Similarity score = 0.02
#
# ====================================
# G1: a072391_c125_2004_2006a_12728776.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 203
# Number of edges: 730
# Average in degree:   3.5961
# Average out degree:   3.5961
#
# G2: a086072_c125_2008_2009a_12463362.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 59
# Number of edges: 82
# Average in degree:   1.3898
# Average out degree:   1.3898
#
# NODE INFORMATION:
# Total nodes in both:  243
# Same nodes in both:  19
# Different nodes in G1:  184
# Different nodes in G2:  40
# --- G1 has 144 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  811
# Same links in both:  1
# Different links in G1:  729
# Different links in G2:  81
# --- G1 has 648 more links than G2.
#
# *** Similarity score = 0.02
#
# ====================================
# G1: a072391_c125_2004_2006a_12728776.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 203
# Number of edges: 730
# Average in degree:   3.5961
# Average out degree:   3.5961
#
# G2: a078348_c125_2004_2008a_15517251.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 45
# Number of edges: 74
# Average in degree:   1.6444
# Average out degree:   1.6444
#
# NODE INFORMATION:
# Total nodes in both:  208
# Same nodes in both:  40
# Different nodes in G1:  163
# Different nodes in G2:  5
# --- G1 has 158 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  740
# Same links in both:  64
# Different links in G1:  666
# Different links in G2:  10
# --- G1 has 656 more links than G2.
#
# *** Similarity score = 0.11
#
# ====================================
# G1: a072391_c125_2004_2006a_12728776.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 203
# Number of edges: 730
# Average in degree:   3.5961
# Average out degree:   3.5961
#
# G2: a075345_c125_2004_2007a_14419765.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 109
# Number of edges: 377
# Average in degree:   3.4587
# Average out degree:   3.4587
#
# NODE INFORMATION:
# Total nodes in both:  226
# Same nodes in both:  86
# Different nodes in G1:  117
# Different nodes in G2:  23
# --- G1 has 94 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  957
# Same links in both:  150
# Different links in G1:  580
# Different links in G2:  227
# --- G1 has 353 more links than G2.
#
# *** Similarity score = 0.20
#
# ====================================
# G1: a086152_c125_1997_2010a_14952469.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 68
# Number of edges: 98
# Average in degree:   1.4412
# Average out degree:   1.4412
#
# G2: a096981_c125_2010.2012a_15102718.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 74
# Number of edges: 111
# Average in degree:   1.5000
# Average out degree:   1.5000
#
# NODE INFORMATION:
# Total nodes in both:  125
# Same nodes in both:  17
# Different nodes in G1:  51
# Different nodes in G2:  57
# --- G2 has 6 more nodes than G1.
#
# LINK INFORMATION:
# Total links in both:  208
# Same links in both:  1
# Different links in G1:  97
# Different links in G2:  110
# --- G2 has 13 more links than G1.
#
# *** Similarity score = 0.05
#
# ====================================
# G1: a086152_c125_1997_2010a_14952469.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 68
# Number of edges: 98
# Average in degree:   1.4412
# Average out degree:   1.4412
#
# G2: a086072_c125_2008_2009a_12463362.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 59
# Number of edges: 82
# Average in degree:   1.3898
# Average out degree:   1.3898
#
# NODE INFORMATION:
# Total nodes in both:  114
# Same nodes in both:  13
# Different nodes in G1:  55
# Different nodes in G2:  46
# --- G1 has 9 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  178
# Same links in both:  2
# Different links in G1:  96
# Different links in G2:  80
# --- G1 has 16 more links than G2.
#
# *** Similarity score = 0.05
#
# ====================================
# G1: a086152_c125_1997_2010a_14952469.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 68
# Number of edges: 98
# Average in degree:   1.4412
# Average out degree:   1.4412
#
# G2: a078348_c125_2004_2008a_15517251.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 45
# Number of edges: 74
# Average in degree:   1.6444
# Average out degree:   1.6444
#
# NODE INFORMATION:
# Total nodes in both:  103
# Same nodes in both:  10
# Different nodes in G1:  58
# Different nodes in G2:  35
# --- G1 has 23 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  170
# Same links in both:  2
# Different links in G1:  96
# Different links in G2:  72
# --- G1 has 24 more links than G2.
#
# *** Similarity score = 0.04
#
# ====================================
# G1: a086152_c125_1997_2010a_14952469.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 68
# Number of edges: 98
# Average in degree:   1.4412
# Average out degree:   1.4412
#
# G2: a075345_c125_2004_2007a_14419765.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 109
# Number of edges: 377
# Average in degree:   3.4587
# Average out degree:   3.4587
#
# NODE INFORMATION:
# Total nodes in both:  162
# Same nodes in both:  15
# Different nodes in G1:  53
# Different nodes in G2:  94
# --- G2 has 41 more nodes than G1.
#
# LINK INFORMATION:
# Total links in both:  472
# Same links in both:  3
# Different links in G1:  95
# Different links in G2:  374
# --- G2 has 279 more links than G1.
#
# *** Similarity score = 0.03
#
# ====================================
# G1: a096981_c125_2010.2012a_15102718.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 74
# Number of edges: 111
# Average in degree:   1.5000
# Average out degree:   1.5000
#
# G2: a086072_c125_2008_2009a_12463362.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 59
# Number of edges: 82
# Average in degree:   1.3898
# Average out degree:   1.3898
#
# NODE INFORMATION:
# Total nodes in both:  117
# Same nodes in both:  16
# Different nodes in G1:  58
# Different nodes in G2:  43
# --- G1 has 15 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  192
# Same links in both:  1
# Different links in G1:  110
# Different links in G2:  81
# --- G1 has 29 more links than G2.
#
# *** Similarity score = 0.06
#
# ====================================
# G1: a096981_c125_2010.2012a_15102718.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 74
# Number of edges: 111
# Average in degree:   1.5000
# Average out degree:   1.5000
#
# G2: a078348_c125_2004_2008a_15517251.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 45
# Number of edges: 74
# Average in degree:   1.6444
# Average out degree:   1.6444
#
# NODE INFORMATION:
# Total nodes in both:  109
# Same nodes in both:  10
# Different nodes in G1:  64
# Different nodes in G2:  35
# --- G1 has 29 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  185
# Same links in both:  0
# Different links in G1:  111
# Different links in G2:  74
# --- G1 has 37 more links than G2.
#
# *** Similarity score = 0.03
#
# ====================================
# G1: a096981_c125_2010.2012a_15102718.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 74
# Number of edges: 111
# Average in degree:   1.5000
# Average out degree:   1.5000
#
# G2: a075345_c125_2004_2007a_14419765.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 109
# Number of edges: 377
# Average in degree:   3.4587
# Average out degree:   3.4587
#
# NODE INFORMATION:
# Total nodes in both:  165
# Same nodes in both:  18
# Different nodes in G1:  56
# Different nodes in G2:  91
# --- G2 has 35 more nodes than G1.
#
# LINK INFORMATION:
# Total links in both:  485
# Same links in both:  3
# Different links in G1:  108
# Different links in G2:  374
# --- G2 has 266 more links than G1.
#
# *** Similarity score = 0.03
#
# ====================================
# G1: a086072_c125_2008_2009a_12463362.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 59
# Number of edges: 82
# Average in degree:   1.3898
# Average out degree:   1.3898
#
# G2: a078348_c125_2004_2008a_15517251.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 45
# Number of edges: 74
# Average in degree:   1.6444
# Average out degree:   1.6444
#
# NODE INFORMATION:
# Total nodes in both:  96
# Same nodes in both:  8
# Different nodes in G1:  51
# Different nodes in G2:  37
# --- G1 has 14 more nodes than G2.
#
# LINK INFORMATION:
# Total links in both:  156
# Same links in both:  0
# Different links in G1:  82
# Different links in G2:  74
# --- G1 has 8 more links than G2.
#
# *** Similarity score = 0.03
#
# ====================================
# G1: a086072_c125_2008_2009a_12463362.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 59
# Number of edges: 82
# Average in degree:   1.3898
# Average out degree:   1.3898
#
# G2: a075345_c125_2004_2007a_14419765.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 109
# Number of edges: 377
# Average in degree:   3.4587
# Average out degree:   3.4587
#
# NODE INFORMATION:
# Total nodes in both:  159
# Same nodes in both:  9
# Different nodes in G1:  50
# Different nodes in G2:  100
# --- G2 has 50 more nodes than G1.
#
# LINK INFORMATION:
# Total links in both:  459
# Same links in both:  0
# Different links in G1:  82
# Different links in G2:  377
# --- G2 has 295 more links than G1.
#
# *** Similarity score = 0.01
#
# ====================================
# G1: a078348_c125_2004_2008a_15517251.json - Graph Name: G1
# Type: DiGraph
# Number of nodes: 45
# Number of edges: 74
# Average in degree:   1.6444
# Average out degree:   1.6444
#
# G2: a075345_c125_2004_2007a_14419765.json - Graph Name: G2
# Type: DiGraph
# Number of nodes: 109
# Number of edges: 377
# Average in degree:   3.4587
# Average out degree:   3.4587
#
# NODE INFORMATION:
# Total nodes in both:  114
# Same nodes in both:  40
# Different nodes in G1:  5
# Different nodes in G2:  69
# --- G2 has 64 more nodes than G1.
#
# LINK INFORMATION:
# Total links in both:  390
# Same links in both:  61
# Different links in G1:  13
# Different links in G2:  316
# --- G2 has 303 more links than G1.
#
# *** Similarity score = 0.20
#
# Num scores =  21
# Total processing time: 00:00:07.00
# FINISHED:  2020-06-30 13:04:22.675805
# [[0.55,
#   'a078606_c125-1997-2008a_12703370.json',
#   'a086152_c125_1997_2010a_14952469.json'],
#  [0.2,
#   'a078348_c125_2004_2008a_15517251.json',
#   'a075345_c125_2004_2007a_14419765.json'],
#  [0.2,
#   'a072391_c125_2004_2006a_12728776.json',
#   'a075345_c125_2004_2007a_14419765.json'],
#  [0.11,
#   'a072391_c125_2004_2006a_12728776.json',
#   'a078348_c125_2004_2008a_15517251.json'],
#  [0.06,
#   'a096981_c125_2010.2012a_15102718.json',
#   'a086072_c125_2008_2009a_12463362.json'],
#  [0.05,
#   'a086152_c125_1997_2010a_14952469.json',
#   'a096981_c125_2010.2012a_15102718.json'],
#  [0.05,
#   'a086152_c125_1997_2010a_14952469.json',
#   'a086072_c125_2008_2009a_12463362.json'],
#  [0.05,
#   'a078606_c125-1997-2008a_12703370.json',
#   'a096981_c125_2010.2012a_15102718.json'],
#  [0.04,
#   'a086152_c125_1997_2010a_14952469.json',
#   'a078348_c125_2004_2008a_15517251.json'],
#  [0.04,
#   'a078606_c125-1997-2008a_12703370.json',
#   'a086072_c125_2008_2009a_12463362.json'],
#  [0.04,
#   'a078606_c125-1997-2008a_12703370.json',
#   'a072391_c125_2004_2006a_12728776.json'],
#  [0.03,
#   'a096981_c125_2010.2012a_15102718.json',
#   'a078348_c125_2004_2008a_15517251.json'],
#  [0.03,
#   'a096981_c125_2010.2012a_15102718.json',
#   'a075345_c125_2004_2007a_14419765.json'],
#  [0.03,
#   'a086152_c125_1997_2010a_14952469.json',
#   'a075345_c125_2004_2007a_14419765.json'],
#  [0.03,
#   'a086072_c125_2008_2009a_12463362.json',
#   'a078348_c125_2004_2008a_15517251.json'],
#  [0.03,
#   'a078606_c125-1997-2008a_12703370.json',
#   'a078348_c125_2004_2008a_15517251.json'],
#  [0.03,
#   'a078606_c125-1997-2008a_12703370.json',
#   'a075345_c125_2004_2007a_14419765.json'],
#  [0.03,
#   'a072391_c125_2004_2006a_12728776.json',
#   'a086152_c125_1997_2010a_14952469.json'],
#  [0.02,
#   'a072391_c125_2004_2006a_12728776.json',
#   'a096981_c125_2010.2012a_15102718.json'],
#  [0.02,
#   'a072391_c125_2004_2006a_12728776.json',
#   'a086072_c125_2008_2009a_12463362.json'],
#  [0.01,
#   'a086072_c125_2008_2009a_12463362.json',
#   'a075345_c125_2004_2007a_14419765.json']]
